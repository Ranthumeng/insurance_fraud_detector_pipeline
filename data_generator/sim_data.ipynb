# %%
pip install "pymongo[srv]==3.12"

# %%
import os
import random
import time
from faker import Faker
import pymongo
from dotenv import load_dotenv
load_dotenv()

# %%
#Initializing
fake = Faker()

# %%
client = pymongo.MongoClient("mongodb+srv://ranthumeng_db_user:ranthumeng@cluster0.hb3x8jr.mongodb.net/?appName=Cluster0")
db = client["Cluster0"]
customers_col = db["customers"]
claims_col = db["claims"]

#setting limit on data ingestion
MAX_RECORDS = 500
records_inserted = 0

while MAX_RECORDS is None or records_inserted < MAX_RECORDS:
    customer = {
        "customer_id": f"CUST-{random.randint(100,999)}",
        "name": fake.name(),
        "state": fake.state_abbr(),
        "policy_type": random.choice(["Auto", "Home", "Health"])
    }

    claim = {
        "claim_id": f"CLM-{random.randint(1000,9999)}",
        "customer_id": customer["customer_id"],
        "date": fake.date_between(start_date='-1y', end_date='today').isoformat(),
        "amount": round(random.uniform(100, 20000), 2),
        "claim_type": random.choice(["Accident", "Theft", "Fire"]),
        "is_fraud": random.random() < 0.05
    }

    # Insert into MongoDB
    customers_col.insert_one(customer)
    claims_col.insert_one(claim)

     # Progress Tracker
    records_inserted += 1

    print(f"Inserted claim {claim['claim_id']} for customer {customer['customer_id']}")

    time.sleep(2)
